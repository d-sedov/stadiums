# %%
################################################################################                                                                                                                                                              
################################################################################
#
# FILE: basketball-matching.ipynb
#
# BY: Dmitry Sedov 
#
# CREATED: Tue Jun 2 2020
#
# DESC: This code matches the stadiums to Sname POI dataset.
#
# EXEC:
#      
################################################################################
################################################################################

# %%
################################ Libraries #####################################

from bs4 import BeautifulSoup
import requests

import re
import os

import pandas as pd

from sqlalchemy.orm import sessionmaker
import sqlalchemy as db
import psycopg2

import us
from Levenshtein import ratio

################################################################################

# %%
################################ Constants #####################################

project_folder = '/home/user/projects/stadiums'
teams_output_folder = os.path.join(project_folder, 'data/basketball/teams/')
games_output_folder = os.path.join(project_folder, 'data/basketball/games/')

################################################################################

# %%
############################ PostgreSQL connection #############################

connection = psycopg2.connect(dbname = 'dataname2', 
                              user = 'user')
cursor = connection.cursor()

################################################################################

# %%
################################ Constants #####################################

def stadium_search(name, state):
    """ Search for a stadium in the database. """
    
    search_query = f"""
    SELECT 
        sname_place_id,
        location_name,
        naics_code,
        top_category,
        sub_category
    FROM 
        establishments
    WHERE
        state = '{state}'
        AND
        LOWER (location_name) LIKE '%{name.lower()}%'
    ;
    """
    results = pd.read_sql(search_query, con = connection)
    results['stadium'] = name
    
    return results

def visits_exist(sname_place_id):
    """Determine whether visits exist for a sname_place_id. """
    
    visits_exist_query = f"""
    SELECT 
        sname_place_id 
    FROM 
        visits 
    WHERE 
        sname_place_id = '{sname_place_id}'
    """
    cursor.execute(visits_exist_query)
    return (cursor.rowcount)

def visits_total(sname_place_id):
    visits_total_query = f"""
    SELECT 
        SUM(raw_visit_counts) 
    FROM 
        visits 
    WHERE 
        sname_place_id = '{sname_place_id}'
    """
    cursor.execute(visits_total_query)
    return (cursor.fetchone()[0])

################################################################################

# %%
def find_potential_matches(row, stadium_column):
    stadium = row[stadium_column]
    state = row['state']
    potential_matches = stadium_search(stadium, state)
    potential_matches['visits_exist'] = potential_matches['sname_place_id'].apply(visits_exist)
    potential_matches['visits_count'] = potential_matches['sname_place_id'].apply(visits_total)
    potential_matches['category_correct'] = potential_matches['naics_code'].apply(lambda x: str(x).startswith('71'))
    potential_matches['name_similarity'] = potential_matches.apply(lambda row: 
                                                               ratio(row['stadium'], row['location_name']), 
                                                               axis = 1)
    potential_matches.sort_values(by = ['visits_exist', 'name_similarity', 'visits_count', 'category_correct'],
                                  ascending = [False, False, False, False],
                                  inplace = True)
    potential_matches.reset_index(inplace = True)
    good_match = potential_matches.loc[0, ['visits_exist', 
                                           'category_correct', 
                                           'name_similarity']].to_list()
    print(potential_matches.loc[0, 'location_name'])
    print(good_match)
    if (good_match[0] >= 1 and good_match[1] and (good_match[2] >= 0.6)):
        return [good_match[0]] + potential_matches.loc[0, ['location_name', 'sname_place_id']].tolist()
    else:
        return None

# %%
############################# Import stadiums names ############################

stadiums = pd.read_csv(os.path.join(teams_output_folder,
                                    'basketball_teams.csv')
                      )
towns = pd.read_csv(os.path.join(teams_output_folder,
                                 'basketball_locations.csv')
                   )
towns.rename(columns = {'City, State': 'City'}, inplace = True)

towns = towns[['Team', 'City']]

stadiums = pd.merge(stadiums, 
                    towns, how = 'left', 
                    left_on = 'name', 
                    right_on = 'Team', 
                    validate = 'one_to_one')

################################################################################

# %%
stadiums['state'] = stadiums['City'].apply(lambda x: x.split(',')[1].strip().lower())
stadiums['city'] = stadiums['City'].apply(lambda x: x.split(',')[0].lower())

# %%
stadiums.drop(columns = [x for x in stadiums.columns 
                         if x not in ['name', 
                                      'city', 
                                      'state',
                                      'stadium_2017',
                                      'stadium_2018', 
                                      'stadium_2019'
                                     ]
                        ], 
              inplace = True)

# %%
stadiums
# Out:
#                       name                stadium_2017  \
# 0            Atlanta Hawks               Philips Arena
# 1           Boston Celtics                   TD Garden
# 2            Brooklyn Nets             Barclays Center
# 3        Charlotte Hornets             Spectrum Center
# 4            Chicago Bulls               United Center
# 5      Cleveland Cavaliers         Quicken Loans Arena
# 6         Dallas Mavericks    American Airlines Center
# 7           Denver Nuggets                Pepsi Center
# 8          Detroit Pistons  The Palace of Auburn Hills
# 9    Golden State Warriors                Oracle Arena
# 10         Houston Rockets               Toyota Center
# 11          Indiana Pacers     Bankers Life Fieldhouse
# 12    Los Angeles Clippers              STAPLES Center
# 13      Los Angeles Lakers              STAPLES Center
# 14       Memphis Grizzlies                 FedEx Forum
# 15              Miami Heat      AmericanAirlines Arena
# 16         Milwaukee Bucks   BMO Harris Bradley Center
# 17  Minnesota Timberwolves               Target Center
# 18    New Orleans Pelicans        Smoothie King Center
# 19         New York Knicks  Madison Square Garden (IV)
# 20   Oklahoma City Thunder     Chesapeake Energy Arena
# 21           Orlando Magic                Amway Center
# 22      Philadelphia 76ers          Wells Fargo Center
# 23            Phoenix Suns  Talking Stick Resort Arena
# 24  Portland Trail Blazers                 Moda Center
# 25        Sacramento Kings             Golden 1 Center
# 26       San Antonio Spurs                 AT&T Center
# 27         Toronto Raptors           Air Canada Centre
# 28               Utah Jazz     Vivint Smart Home Arena
# 29      Washington Wizards              Verizon Center
#
#                   stadium_2018                stadium_2019           state  \
# 0                Philips Arena            State Farm Arena         georgia
# 1                    TD Garden                   TD Garden   massachusetts
# 2              Barclays Center             Barclays Center        new york
# 3              Spectrum Center             Spectrum Center  north carolina
# 4                United Center               United Center        illinois
# 5          Quicken Loans Arena         Quicken Loans Arena            ohio
# 6     American Airlines Center    American Airlines Center           texas
# 7                 Pepsi Center                Pepsi Center        colorado
# 8         Little Caesars Arena        Little Caesars Arena        michigan
# 9                 Oracle Arena                Oracle Arena      california
# 10               Toyota Center               Toyota Center           texas
# 11     Bankers Life Fieldhouse     Bankers Life Fieldhouse         indiana
# 12              STAPLES Center              STAPLES Center      california
# 13              STAPLES Center              STAPLES Center      california
# 14                 FedEx Forum                 FedEx Forum       tennessee
# 15      AmericanAirlines Arena      AmericanAirlines Arena         florida
# 16   BMO Harris Bradley Center                Fiserv Forum       wisconsin
# 17               Target Center               Target Center       minnesota
# 18        Smoothie King Center        Smoothie King Center       louisiana
# 19  Madison Square Garden (IV)  Madison Square Garden (IV)        new york
# 20     Chesapeake Energy Arena     Chesapeake Energy Arena        oklahoma
# 21                Amway Center                Amway Center         florida
# 22          Wells Fargo Center          Wells Fargo Center    pennsylvania
# 23  Talking Stick Resort Arena  Talking Stick Resort Arena         arizona
# 24                 Moda Center                 Moda Center          oregon
# 25             Golden 1 Center             Golden 1 Center      california
# 26                 AT&T Center                 AT&T Center           texas
# 27           Air Canada Centre            Scotiabank Arena         ontario
# 28     Vivint Smart Home Arena     Vivint Smart Home Arena            utah
# 29           Capital One Arena           Capital One Arena            d.c.
#
#               city
# 0          atlanta
# 1           boston
# 2    new york city
# 3        charlotte
# 4          chicago
# 5        cleveland
# 6           dallas
# 7           denver
# 8          detroit
# 9    san francisco
# 10         houston
# 11    indianapolis
# 12     los angeles
# 13     los angeles
# 14         memphis
# 15           miami
# 16       milwaukee
# 17     minneapolis
# 18     new orleans
# 19   new york city
# 20   oklahoma city
# 21         orlando
# 22    philadelphia
# 23         phoenix
# 24        portland
# 25      sacramento
# 26     san antonio
# 27         toronto
# 28  salt lake city
# 29      washington

# %%
for i, row in stadiums.iterrows():
    try:
        stadiums.loc[i, 'state'] = us.states.lookup(row['state'
                                                       ].replace('.',
                                                                 '')
                                                   ).abbr.lower()
    except AttributeError:
        stadiums.loc[i,'state'] = None

# %%
# Find stadium columns
stadium_columns = [x for x in stadiums.columns if 'stadium' in x]

# %%
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'Spectrum Center', 
                                                              value = 'Time Warner Cable Arena')
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'STAPLES Center', 
                                                              value = 'Staples Center')
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'FedEx Forum', 
                                                              value = 'FedExForum')
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'AmericanAirlines Arena', 
                                                              value = 'American Airlines Arena')
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'Madison Square Garden (IV)', 
                                                              value = 'Madison Square Garden')
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = '', 
                                                              value = 'Madison Square Garden')
# Replace the new name with the old one - as in SG database
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'State Farm Arena', 
                                                              value = 'Philips Arena')
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'Capital One Arena', 
                                                              value = 'Verizon Center')

# %%
# Iterate through stadium columns and find matches in SG dataset
for stadium_column in stadium_columns:
    y = stadium_column.split('_')[1]
    m = f'good_match_{y}' 
    stadiums[m] = None
    for i, row in stadiums.iterrows():
        try:
            stadiums.loc[i, m] = find_potential_matches(row, stadium_column)
        except ValueError:
            stadiums.loc[i, m] = None
# Out:
# Philips Arena
# [26, True, 1.0]
# Td Garden
# [26, True, 0.8888888888888888]
# Barclays Center
# [26, True, 1.0]
# Time Warner Cable Arena
# [26, True, 1.0]
# United Center
# [26, True, 1.0]
# Quicken Loans Arena
# [1, True, 1.0]
# American Airlines Center
# [26, True, 1.0]
# Pepsi Center
# [26, True, 1.0]
# The Palace Of Auburn Hills
# [26, True, 0.9615384615384616]
# Oracle Arena
# [26, True, 1.0]
# toyota center
# [26, False, 0.8461538461538461]
# Bankers Life Fieldhouse
# [26, True, 1.0]
# Staples Center
# [26, True, 1.0]
# Staples Center
# [26, True, 1.0]
# Fedexforum
# [26, True, 0.8]
# American Airlines Arena
# [26, True, 1.0]
# Bmo Harris Bradley Center
# [26, True, 0.92]
# Target Center
# [26, True, 1.0]
# Smoothie King Center
# [26, True, 1.0]
# Madison Square Garden
# [26, True, 1.0]
# Chesapeake Energy Arena
# [26, True, 1.0]
# Amway Center
# [26, True, 1.0]
# Wells Fargo Center
# [26, True, 1.0]
# Talking Stick Resort Arena
# [26, True, 1.0]
# Moda Center
# [26, True, 1.0]
# At&t Center
# [26, True, 0.8181818181818182]
# Vivint Smart Home Arena
# [26, True, 1.0]
# Verizon Center
# [26, True, 1.0]
# Philips Arena
# [26, True, 1.0]
# Td Garden
# [26, True, 0.8888888888888888]
# Barclays Center
# [26, True, 1.0]
# Time Warner Cable Arena
# [26, True, 1.0]
# United Center
# [26, True, 1.0]
# Quicken Loans Arena
# [1, True, 1.0]
# American Airlines Center
# [26, True, 1.0]
# Pepsi Center
# [26, True, 1.0]
# Little Caesars Arena
# [26, True, 1.0]
# Oracle Arena
# [26, True, 1.0]
# toyota center
# [26, False, 0.8461538461538461]
# Bankers Life Fieldhouse
# [26, True, 1.0]
# Staples Center
# [26, True, 1.0]
# Staples Center
# [26, True, 1.0]
# Fedexforum
# [26, True, 0.8]
# American Airlines Arena
# [26, True, 1.0]
# Bmo Harris Bradley Center
# [26, True, 0.92]
# Target Center
# [26, True, 1.0]
# Smoothie King Center
# [26, True, 1.0]
# Madison Square Garden
# [26, True, 1.0]
# Chesapeake Energy Arena
# [26, True, 1.0]
# Amway Center
# [26, True, 1.0]
# Wells Fargo Center
# [26, True, 1.0]
# Talking Stick Resort Arena
# [26, True, 1.0]
# Moda Center
# [26, True, 1.0]
# At&t Center
# [26, True, 0.8181818181818182]
# Vivint Smart Home Arena
# [26, True, 1.0]
# Verizon Center
# [26, True, 1.0]
# Philips Arena
# [26, True, 1.0]
# Td Garden
# [26, True, 0.8888888888888888]
# Barclays Center
# [26, True, 1.0]
# Time Warner Cable Arena
# [26, True, 1.0]
# United Center
# [26, True, 1.0]
# Quicken Loans Arena
# [1, True, 1.0]
# American Airlines Center
# [26, True, 1.0]
# Pepsi Center
# [26, True, 1.0]
# Little Caesars Arena
# [26, True, 1.0]
# Oracle Arena
# [26, True, 1.0]
# toyota center
# [26, False, 0.8461538461538461]
# Bankers Life Fieldhouse
# [26, True, 1.0]
# Staples Center
# [26, True, 1.0]
# Staples Center
# [26, True, 1.0]
# Fedexforum
# [26, True, 0.8]
# American Airlines Arena
# [26, True, 1.0]
# Fiserv Forum
# [26, True, 1.0]
# Target Center
# [26, True, 1.0]
# Smoothie King Center
# [26, True, 1.0]
# Madison Square Garden
# [26, True, 1.0]
# Chesapeake Energy Arena
# [26, True, 1.0]
# Amway Center
# [26, True, 1.0]
# Wells Fargo Center
# [26, True, 1.0]
# Talking Stick Resort Arena
# [26, True, 1.0]
# Moda Center
# [26, True, 1.0]
# At&t Center
# [26, True, 0.8181818181818182]
# Vivint Smart Home Arena
# [26, True, 1.0]
# Verizon Center
# [26, True, 1.0]

# %%
towns
# Out:
#                       Team                        City
# 0            Atlanta Hawks            Atlanta, Georgia
# 1           Boston Celtics       Boston, Massachusetts
# 2            Brooklyn Nets     New York City, New York
# 3        Charlotte Hornets   Charlotte, North Carolina
# 4            Chicago Bulls           Chicago, Illinois
# 5      Cleveland Cavaliers             Cleveland, Ohio
# 6         Dallas Mavericks               Dallas, Texas
# 7           Denver Nuggets            Denver, Colorado
# 8          Detroit Pistons           Detroit, Michigan
# 9    Golden State Warriors   San Francisco, California
# 10         Houston Rockets              Houston, Texas
# 11          Indiana Pacers       Indianapolis, Indiana
# 12    Los Angeles Clippers     Los Angeles, California
# 13      Los Angeles Lakers     Los Angeles, California
# 14       Memphis Grizzlies          Memphis, Tennessee
# 15              Miami Heat              Miami, Florida
# 16         Milwaukee Bucks        Milwaukee, Wisconsin
# 17  Minnesota Timberwolves      Minneapolis, Minnesota
# 18    New Orleans Pelicans      New Orleans, Louisiana
# 19         New York Knicks     New York City, New York
# 20   Oklahoma City Thunder     Oklahoma City, Oklahoma
# 21           Orlando Magic            Orlando, Florida
# 22      Philadelphia 76ers  Philadelphia, Pennsylvania
# 23            Phoenix Suns            Phoenix, Arizona
# 24  Portland Trail Blazers            Portland, Oregon
# 25        Sacramento Kings      Sacramento, California
# 26       San Antonio Spurs          San Antonio, Texas
# 27         Toronto Raptors            Toronto, Ontario
# 28               Utah Jazz        Salt Lake City, Utah
# 29      Washington Wizards            Washington, D.C.

# %%
stadiums
# Out:
#                       name                stadium_2017  \
# 0            Atlanta Hawks               Philips Arena
# 1           Boston Celtics                   TD Garden
# 2            Brooklyn Nets             Barclays Center
# 3        Charlotte Hornets     Time Warner Cable Arena
# 4            Chicago Bulls               United Center
# 5      Cleveland Cavaliers         Quicken Loans Arena
# 6         Dallas Mavericks    American Airlines Center
# 7           Denver Nuggets                Pepsi Center
# 8          Detroit Pistons  The Palace of Auburn Hills
# 9    Golden State Warriors                Oracle Arena
# 10         Houston Rockets               Toyota Center
# 11          Indiana Pacers     Bankers Life Fieldhouse
# 12    Los Angeles Clippers              Staples Center
# 13      Los Angeles Lakers              Staples Center
# 14       Memphis Grizzlies                  FedExForum
# 15              Miami Heat     American Airlines Arena
# 16         Milwaukee Bucks   BMO Harris Bradley Center
# 17  Minnesota Timberwolves               Target Center
# 18    New Orleans Pelicans        Smoothie King Center
# 19         New York Knicks       Madison Square Garden
# 20   Oklahoma City Thunder     Chesapeake Energy Arena
# 21           Orlando Magic                Amway Center
# 22      Philadelphia 76ers          Wells Fargo Center
# 23            Phoenix Suns  Talking Stick Resort Arena
# 24  Portland Trail Blazers                 Moda Center
# 25        Sacramento Kings             Golden 1 Center
# 26       San Antonio Spurs                 AT&T Center
# 27         Toronto Raptors           Air Canada Centre
# 28               Utah Jazz     Vivint Smart Home Arena
# 29      Washington Wizards              Verizon Center
#
#                   stadium_2018                stadium_2019 state  \
# 0                Philips Arena               Philips Arena    ga
# 1                    TD Garden                   TD Garden    ma
# 2              Barclays Center             Barclays Center    ny
# 3      Time Warner Cable Arena     Time Warner Cable Arena    nc
# 4                United Center               United Center    il
# 5          Quicken Loans Arena         Quicken Loans Arena    oh
# 6     American Airlines Center    American Airlines Center    tx
# 7                 Pepsi Center                Pepsi Center    co
# 8         Little Caesars Arena        Little Caesars Arena    mi
# 9                 Oracle Arena                Oracle Arena    ca
# 10               Toyota Center               Toyota Center    tx
# 11     Bankers Life Fieldhouse     Bankers Life Fieldhouse    in
# 12              Staples Center              Staples Center    ca
# 13              Staples Center              Staples Center    ca
# 14                  FedExForum                  FedExForum    tn
# 15     American Airlines Arena     American Airlines Arena    fl
# 16   BMO Harris Bradley Center                Fiserv Forum    wi
# 17               Target Center               Target Center    mn
# 18        Smoothie King Center        Smoothie King Center    la
# 19       Madison Square Garden       Madison Square Garden    ny
# 20     Chesapeake Energy Arena     Chesapeake Energy Arena    ok
# 21                Amway Center                Amway Center    fl
# 22          Wells Fargo Center          Wells Fargo Center    pa
# 23  Talking Stick Resort Arena  Talking Stick Resort Arena    az
# 24                 Moda Center                 Moda Center    or
# 25             Golden 1 Center             Golden 1 Center    ca
# 26                 AT&T Center                 AT&T Center    tx
# 27           Air Canada Centre            Scotiabank Arena  None
# 28     Vivint Smart Home Arena     Vivint Smart Home Arena    ut
# 29              Verizon Center              Verizon Center    dc
#
#               city                                    good_match_2017  \
# 0          atlanta  [26, Philips Arena, sg:c7c2dbe83bfb4a88a26ca9a...
# 1           boston  [26, Td Garden, sg:2a96716e3b8a4f0e9dfc249ac7c...
# 2    new york city  [26, Barclays Center, sg:a4375f84884541bca5628...
# 3        charlotte  [26, Time Warner Cable Arena, sg:be683bc19f2d4...
# 4          chicago  [26, United Center, sg:ae4d4adf1c4a4ace882a3f5...
# 5        cleveland  [1, Quicken Loans Arena, sg:e5a38ec18fc44c8593...
# 6           dallas  [26, American Airlines Center, sg:f79998a4f42d...
# 7           denver  [26, Pepsi Center, sg:e7385ac76b2546c9b905be12...
# 8          detroit  [26, The Palace Of Auburn Hills, sg:3c36843e94...
# 9    san francisco  [26, Oracle Arena, sg:bfae5fecd9b94aeab823761c...
# 10         houston                                               None
# 11    indianapolis  [26, Bankers Life Fieldhouse, sg:132c73b318184...
# 12     los angeles  [26, Staples Center, sg:c4899bdca8564210a4cbc6...
# 13     los angeles  [26, Staples Center, sg:c4899bdca8564210a4cbc6...
# 14         memphis  [26, Fedexforum, sg:fee7603fe21e4a559248eb1a8f...
# 15           miami  [26, American Airlines Arena, sg:d63edf233f464...
# 16       milwaukee  [26, Bmo Harris Bradley Center, sg:022558c60a6...
# 17     minneapolis  [26, Target Center, sg:cd0f6e05f9cb4de49f4cda2...
# 18     new orleans  [26, Smoothie King Center, sg:10c2a7bec1164a18...
# 19   new york city  [26, Madison Square Garden, sg:1cc8dbe5600542c...
# 20   oklahoma city  [26, Chesapeake Energy Arena, sg:43f28b2a1bf94...
# 21         orlando  [26, Amway Center, sg:082e609ab2c544d6b33bec38...
# 22    philadelphia  [26, Wells Fargo Center, sg:781e08237713408aa4...
# 23         phoenix  [26, Talking Stick Resort Arena, sg:bce957197f...
# 24        portland  [26, Moda Center, sg:964ff3c571cc4b2b8059e46d2...
# 25      sacramento                                               None
# 26     san antonio  [26, At&t Center, sg:e6f4051b54ef48fc84a892a95...
# 27         toronto                                               None
# 28  salt lake city  [26, Vivint Smart Home Arena, sg:1b7995eb55314...
# 29      washington  [26, Verizon Center, sg:008eedc461cd430f8be8e2...
#
#                                       good_match_2018  \
# 0   [26, Philips Arena, sg:c7c2dbe83bfb4a88a26ca9a...
# 1   [26, Td Garden, sg:2a96716e3b8a4f0e9dfc249ac7c...
# 2   [26, Barclays Center, sg:a4375f84884541bca5628...
# 3   [26, Time Warner Cable Arena, sg:be683bc19f2d4...
# 4   [26, United Center, sg:ae4d4adf1c4a4ace882a3f5...
# 5   [1, Quicken Loans Arena, sg:e5a38ec18fc44c8593...
# 6   [26, American Airlines Center, sg:f79998a4f42d...
# 7   [26, Pepsi Center, sg:e7385ac76b2546c9b905be12...
# 8   [26, Little Caesars Arena, sg:461065e801484d2e...
# 9   [26, Oracle Arena, sg:bfae5fecd9b94aeab823761c...
# 10                                               None
# 11  [26, Bankers Life Fieldhouse, sg:132c73b318184...
# 12  [26, Staples Center, sg:c4899bdca8564210a4cbc6...
# 13  [26, Staples Center, sg:c4899bdca8564210a4cbc6...
# 14  [26, Fedexforum, sg:fee7603fe21e4a559248eb1a8f...
# 15  [26, American Airlines Arena, sg:d63edf233f464...
# 16  [26, Bmo Harris Bradley Center, sg:022558c60a6...
# 17  [26, Target Center, sg:cd0f6e05f9cb4de49f4cda2...
# 18  [26, Smoothie King Center, sg:10c2a7bec1164a18...
# 19  [26, Madison Square Garden, sg:1cc8dbe5600542c...
# 20  [26, Chesapeake Energy Arena, sg:43f28b2a1bf94...
# 21  [26, Amway Center, sg:082e609ab2c544d6b33bec38...
# 22  [26, Wells Fargo Center, sg:781e08237713408aa4...
# 23  [26, Talking Stick Resort Arena, sg:bce957197f...
# 24  [26, Moda Center, sg:964ff3c571cc4b2b8059e46d2...
# 25                                               None
# 26  [26, At&t Center, sg:e6f4051b54ef48fc84a892a95...
# 27                                               None
# 28  [26, Vivint Smart Home Arena, sg:1b7995eb55314...
# 29  [26, Verizon Center, sg:008eedc461cd430f8be8e2...
#
#                                       good_match_2019
# 0   [26, Philips Arena, sg:c7c2dbe83bfb4a88a26ca9a...
# 1   [26, Td Garden, sg:2a96716e3b8a4f0e9dfc249ac7c...
# 2   [26, Barclays Center, sg:a4375f84884541bca5628...
# 3   [26, Time Warner Cable Arena, sg:be683bc19f2d4...
# 4   [26, United Center, sg:ae4d4adf1c4a4ace882a3f5...
# 5   [1, Quicken Loans Arena, sg:e5a38ec18fc44c8593...
# 6   [26, American Airlines Center, sg:f79998a4f42d...
# 7   [26, Pepsi Center, sg:e7385ac76b2546c9b905be12...
# 8   [26, Little Caesars Arena, sg:461065e801484d2e...
# 9   [26, Oracle Arena, sg:bfae5fecd9b94aeab823761c...
# 10                                               None
# 11  [26, Bankers Life Fieldhouse, sg:132c73b318184...
# 12  [26, Staples Center, sg:c4899bdca8564210a4cbc6...
# 13  [26, Staples Center, sg:c4899bdca8564210a4cbc6...
# 14  [26, Fedexforum, sg:fee7603fe21e4a559248eb1a8f...
# 15  [26, American Airlines Arena, sg:d63edf233f464...
# 16  [26, Fiserv Forum, sg:ad45e77a539642379c11d3b9...
# 17  [26, Target Center, sg:cd0f6e05f9cb4de49f4cda2...
# 18  [26, Smoothie King Center, sg:10c2a7bec1164a18...
# 19  [26, Madison Square Garden, sg:1cc8dbe5600542c...
# 20  [26, Chesapeake Energy Arena, sg:43f28b2a1bf94...
# 21  [26, Amway Center, sg:082e609ab2c544d6b33bec38...
# 22  [26, Wells Fargo Center, sg:781e08237713408aa4...
# 23  [26, Talking Stick Resort Arena, sg:bce957197f...
# 24  [26, Moda Center, sg:964ff3c571cc4b2b8059e46d2...
# 25                                               None
# 26  [26, At&t Center, sg:e6f4051b54ef48fc84a892a95...
# 27                                               None
# 28  [26, Vivint Smart Home Arena, sg:1b7995eb55314...
# 29  [26, Verizon Center, sg:008eedc461cd430f8be8e2...

# %%
stadiums['sg_id_2017'] = stadiums['good_match_2017'].apply(lambda x: x[2] if x else None)
stadiums['sg_id_2018'] = stadiums['good_match_2018'].apply(lambda x: x[2] if x else None)
stadiums['sg_id_2019'] = stadiums['good_match_2019'].apply(lambda x: x[2] if x else None)

# %%
# Export the matching
output_file_path = os.path.join(teams_output_folder, 'basketball_matching.csv')
stadiums[['name', 'sg_id_2017', 'sg_id_2018', 'sg_id_2019']].to_csv(output_file_path, 
                                                                    index = False)
