# %%
################################################################################                                                                                                                                                              
################################################################################
#
# FILE: hockey-matching.ipynb
#
# BY: Dmitry Sedov 
#
# CREATED: Tue Jun 2 2020
#
# DESC: This code matches the stadiums to Sname POI dataset.
#
# EXEC:
#      
################################################################################
################################################################################

# %%
################################ Libraries #####################################

from bs4 import BeautifulSoup
import requests

import re
import os

import pandas as pd

from sqlalchemy.orm import sessionmaker
import sqlalchemy as db
import psycopg2

import us
from Levenshtein import ratio

################################################################################

# %%
################################ Constants #####################################

project_folder = '/home/user/projects/stadiums'
teams_output_folder = os.path.join(project_folder, 'data/hockey/teams/')
games_output_folder = os.path.join(project_folder, 'data/hockey/games/')

################################################################################

# %%
############################ PostgreSQL connection #############################

connection = psycopg2.connect(dbname = 'dataname2', 
                              user = 'user')
cursor = connection.cursor()

################################################################################

# %%
################################ Constants #####################################

def stadium_search(name, state):
    """ Search for a stadium in the database. """
    
    search_query = f"""
    SELECT 
        sname_place_id,
        location_name,
        naics_code,
        top_category,
        sub_category
    FROM 
        establishments
    WHERE
        state = '{state}'
        AND
        LOWER (location_name) LIKE $$%{name.lower()}%$$
    ;
    """
    results = pd.read_sql(search_query, con = connection)
    results['stadium'] = name
    
    return results

def visits_exist(sname_place_id):
    """Determine whether visits exist for a sname_place_id. """
    
    visits_exist_query = f"""
    SELECT 
        sname_place_id 
    FROM 
        visits 
    WHERE 
        sname_place_id = '{sname_place_id}'
    """
    cursor.execute(visits_exist_query)
    return (cursor.rowcount)

def visits_total(sname_place_id):
    visits_total_query = f"""
    SELECT 
        SUM(raw_visit_counts) 
    FROM 
        visits 
    WHERE 
        sname_place_id = '{sname_place_id}'
    """
    cursor.execute(visits_total_query)
    return (cursor.fetchone()[0])

################################################################################

# %%
def find_potential_matches(row, stadium_column):
    stadium = row[stadium_column]
    state = row['state']
    potential_matches = stadium_search(stadium, state)
    potential_matches['visits_exist'] = potential_matches['sname_place_id'].apply(visits_exist)
    potential_matches['visits_count'] = potential_matches['sname_place_id'].apply(visits_total)
    potential_matches['category_correct'] = potential_matches['naics_code'].apply(lambda x: str(x).startswith('71'))
    potential_matches['name_similarity'] = potential_matches.apply(lambda row: 
                                                               ratio(row['stadium'], row['location_name']), 
                                                               axis = 1)
    potential_matches.sort_values(by = ['name_similarity', 'visits_exist', 'visits_count', 'category_correct'],
                                  ascending = [False, False, False, False],
                                  inplace = True)
    potential_matches.reset_index(inplace = True)
    good_match = potential_matches.loc[0, ['visits_exist', 
                                           'category_correct', 
                                           'name_similarity']].to_list()
    print(potential_matches.loc[0, 'location_name'])
    print(good_match)
    if (good_match[0] >= 1 and good_match[1] and (good_match[2] >= 0.6)):
        return [good_match[0]] + potential_matches.loc[0, ['location_name', 'sname_place_id']].tolist()
    elif (not good_match[1] and good_match[0] >= 1 and (good_match[2] >= 0.6)):
        return ['!', good_match[0]] + potential_matches.loc[0, ['location_name', 'sname_place_id']].tolist()
    else:
        return None

# %%
############################# Import stadiums names ############################

stadiums = pd.read_csv(os.path.join(teams_output_folder,
                                    'hockey_teams.csv')
                      )

towns = pd.read_csv(os.path.join(teams_output_folder,
                                 'hockey_locations.csv')
                   )
towns.rename(columns = {'City, State': 'City'}, inplace = True)

towns = towns[['Team', 'City']]
towns['Team'] = towns['Team'].replace(to_replace = 'Arizona Coyotesnb ', 
                                      value = 'Arizona Coyotes')
towns['Team'] = towns['Team'].replace(to_replace = 'St Louis Blues', 
                                      value = 'St. Louis Blues')
towns['City'] = towns['City'].replace(to_replace = 'New York City, New YorkUniondale, New York', 
                                      value = 'New York City, New York')

stadiums = pd.merge(stadiums, 
                    towns, how = 'left', 
                    left_on = 'name', 
                    right_on = 'Team', 
                    validate = 'one_to_one')

stadiums.loc[stadiums['name'] == 'Vegas Golden Knights', 'stadium_2017'] = 'T-Mobile Arena'

################################################################################

# %%
stadiums['state'] = stadiums['City'].apply(lambda x: x.split(',')[1].strip().lower())
stadiums['city'] = stadiums['City'].apply(lambda x: x.split(',')[0].lower())

# %%
stadiums.drop(columns = [x for x in stadiums.columns 
                         if x not in ['name', 
                                      'city', 
                                      'state',
                                      'stadium_2017',
                                      'stadium_2018', 
                                      'stadium_2019'
                                     ]
                        ], 
              inplace = True)

# %%
for i, row in stadiums.iterrows():
    try:
        stadiums.loc[i, 'state'] = us.states.lookup(row['state'
                                                       ].replace('.',
                                                                 '')
                                                   ).abbr.lower()
    except AttributeError:
        stadiums.loc[i,'state'] = None

# %%
# Find stadium columns
stadium_columns = [x for x in stadiums.columns if 'stadium' in x]

# %%
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'STAPLES Center', 
                                                              value = 'Staples Center')
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'KeyBank Center', 
                                                              value = 'First Niagara Center')
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'Madison Square Garden (IV)', 
                                                              value = 'Madison Square Garden')
# Replace the new name with the old one - as in SG database
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'State Farm Arena', 
                                                              value = 'Philips Arena')
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'Capital One Arena', 
                                                              value = 'Verizon Center')
# Trick
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'TD Garden', 
                                                              value = 'Td Garden')
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'BB&T Center', 
                                                              value = 'Bb&t Cente')
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'PNC Arena', 
                                                              value = 'Pnc Arena')
stadiums[stadium_columns] = stadiums[stadium_columns].replace(to_replace = 'SAP Center at San Jose', 
                                                              value = 'Sap Center at San Jose')

# %%
# Iterate through stadium columns and find matches in SG dataset
for stadium_column in stadium_columns:
    y = stadium_column.split('_')[1]
    m = f'good_match_{y}' 
    stadiums[m] = None
    for i, row in stadiums.iterrows():
        try:
            stadiums.loc[i, m] = find_potential_matches(row, stadium_column)
        except ValueError:
            stadiums.loc[i, m] = None
# Out:
# Honda Center
# [2, True, 1.0]
# Gila River Arena
# [0, True, 1.0]
# Td Garden
# [26, True, 1.0]
# First Niagara Center
# [26, True, 1.0]
# Pnc Arena
# [26, True, 1.0]
# United Center
# [26, True, 1.0]
# Pepsi Center
# [26, True, 1.0]
# Nationwide Arena
# [26, True, 1.0]
# American Airlines Center
# [26, True, 1.0]
# Joe Louis Arena
# [26, True, 1.0]
# Bb&t Center
# [26, True, 0.9523809523809523]
# Staples Center
# [26, True, 1.0]
# Xcel Energy Center
# [26, True, 1.0]
# Bridgestone Arena
# [26, True, 1.0]
# Prudential Center
# [26, True, 1.0]
# Barclays Center
# [26, True, 1.0]
# Madison Square Garden
# [26, True, 1.0]
# Wells Fargo Center
# [26, True, 1.0]
# PPG Paints Arena
# [25, True, 1.0]
# Sap Center At San Jose
# [26, True, 0.9545454545454546]
# Scottrade Center
# [26, True, 1.0]
# Amalie Arena
# [26, True, 1.0]
# Verizon Center
# [26, True, 1.0]
# Honda Center
# [2, True, 1.0]
# Gila River Arena
# [0, True, 1.0]
# Td Garden
# [26, True, 1.0]
# First Niagara Center
# [26, True, 1.0]
# Pnc Arena
# [26, True, 1.0]
# United Center
# [26, True, 1.0]
# Pepsi Center
# [26, True, 1.0]
# Nationwide Arena
# [26, True, 1.0]
# American Airlines Center
# [26, True, 1.0]
# Little Caesars Arena
# [26, True, 1.0]
# Bb&t Center
# [26, True, 0.9523809523809523]
# Staples Center
# [26, True, 1.0]
# Xcel Energy Center
# [26, True, 1.0]
# Bridgestone Arena
# [26, True, 1.0]
# Prudential Center
# [26, True, 1.0]
# Barclays Center
# [26, True, 1.0]
# Madison Square Garden
# [26, True, 1.0]
# Wells Fargo Center
# [26, True, 1.0]
# PPG Paints Arena
# [25, True, 1.0]
# Sap Center At San Jose
# [26, True, 0.9545454545454546]
# Scottrade Center
# [26, True, 1.0]
# Amalie Arena
# [26, True, 1.0]
# Verizon Center
# [26, True, 1.0]
# Honda Center
# [2, True, 1.0]
# Gila River Arena
# [0, True, 1.0]
# Td Garden
# [26, True, 1.0]
# First Niagara Center
# [26, True, 1.0]
# Pnc Arena
# [26, True, 1.0]
# United Center
# [26, True, 1.0]
# Pepsi Center
# [26, True, 1.0]
# Nationwide Arena
# [26, True, 1.0]
# American Airlines Center
# [26, True, 1.0]
# Little Caesars Arena
# [26, True, 1.0]
# Bb&t Center
# [26, True, 0.9523809523809523]
# Staples Center
# [26, True, 1.0]
# Xcel Energy Center
# [26, True, 1.0]
# Bridgestone Arena
# [26, True, 1.0]
# Prudential Center
# [26, True, 1.0]
# Barclays Center
# [26, True, 1.0]
# Madison Square Garden
# [26, True, 1.0]
# Wells Fargo Center
# [26, True, 1.0]
# PPG Paints Arena
# [25, True, 1.0]
# Sap Center At San Jose
# [26, True, 0.9545454545454546]
# Enterprise Center
# [26, True, 1.0]
# Amalie Arena
# [26, True, 1.0]
# Verizon Center
# [26, True, 1.0]

# %%
stadiums
# Out:
#                      name              stadium_2017              stadium_2018  \
# 0           Anaheim Ducks              Honda Center              Honda Center
# 1         Arizona Coyotes          Gila River Arena          Gila River Arena
# 2           Boston Bruins                 Td Garden                 Td Garden
# 3          Buffalo Sabres      First Niagara Center      First Niagara Center
# 4          Calgary Flames     Scotiabank Saddledome     Scotiabank Saddledome
# 5     Carolina Hurricanes                 Pnc Arena                 Pnc Arena
# 6      Chicago Blackhawks             United Center             United Center
# 7      Colorado Avalanche              Pepsi Center              Pepsi Center
# 8   Columbus Blue Jackets          Nationwide Arena          Nationwide Arena
# 9            Dallas Stars  American Airlines Center  American Airlines Center
# 10      Detroit Red Wings           Joe Louis Arena      Little Caesars Arena
# 11        Edmonton Oilers              Rogers Place              Rogers Place
# 12       Florida Panthers                Bb&t Cente                Bb&t Cente
# 13      Los Angeles Kings            Staples Center            Staples Center
# 14         Minnesota Wild        Xcel Energy Center        Xcel Energy Center
# 15     Montreal Canadiens               Bell Centre               Bell Centre
# 16    Nashville Predators         Bridgestone Arena         Bridgestone Arena
# 17      New Jersey Devils         Prudential Center         Prudential Center
# 18     New York Islanders           Barclays Center           Barclays Center
# 19       New York Rangers     Madison Square Garden     Madison Square Garden
# 20        Ottawa Senators      Canadian Tire Centre      Canadian Tire Centre
# 21    Philadelphia Flyers        Wells Fargo Center        Wells Fargo Center
# 22    Pittsburgh Penguins          PPG Paints Arena          PPG Paints Arena
# 23        San Jose Sharks    Sap Center at San Jose    Sap Center at San Jose
# 24        St. Louis Blues          Scottrade Center          Scottrade Center
# 25    Tampa Bay Lightning              Amalie Arena              Amalie Arena
# 26    Toronto Maple Leafs         Air Canada Centre         Air Canada Centre
# 27      Vancouver Canucks              Rogers Arena              Rogers Arena
# 28   Vegas Golden Knights            T-Mobile Arena            T-Mobile Arena
# 29    Washington Capitals            Verizon Center            Verizon Center
# 30          Winnipeg Jets                MTS Centre            Bell MTS Place
#
#                 stadium_2019 state           city  \
# 0               Honda Center    ca        anaheim
# 1           Gila River Arena    az       glendale
# 2                  Td Garden    ma         boston
# 3       First Niagara Center    ny        buffalo
# 4      Scotiabank Saddledome  None        calgary
# 5                  Pnc Arena    nc        raleigh
# 6              United Center    il        chicago
# 7               Pepsi Center    co         denver
# 8           Nationwide Arena    oh       columbus
# 9   American Airlines Center    tx         dallas
# 10      Little Caesars Arena    mi        detroit
# 11              Rogers Place  None       edmonton
# 12                Bb&t Cente    fl        sunrise
# 13            Staples Center    ca    los angeles
# 14        Xcel Energy Center    mn     saint paul
# 15               Bell Centre  None       montreal
# 16         Bridgestone Arena    tn      nashville
# 17         Prudential Center    nj         newark
# 18           Barclays Center    ny  new york city
# 19     Madison Square Garden    ny  new york city
# 20      Canadian Tire Centre  None         ottawa
# 21        Wells Fargo Center    pa   philadelphia
# 22          PPG Paints Arena    pa     pittsburgh
# 23    Sap Center at San Jose    ca       san jose
# 24         Enterprise Center    mo      st. louis
# 25              Amalie Arena    fl          tampa
# 26          Scotiabank Arena  None        toronto
# 27              Rogers Arena  None      vancouver
# 28            T-Mobile Arena    nv       paradise
# 29            Verizon Center    dc     washington
# 30            Bell MTS Place  None       winnipeg
#
#                                       good_match_2017  \
# 0   [2, Honda Center, sg:1a660f827ee040e5bbb6da664...
# 1                                                None
# 2   [26, Td Garden, sg:2a96716e3b8a4f0e9dfc249ac7c...
# 3   [26, First Niagara Center, sg:74d5a8291f1345b4...
# 4                                                None
# 5   [26, Pnc Arena, sg:ac283081b6e44c1cb19feb1a5ce...
# 6   [26, United Center, sg:ae4d4adf1c4a4ace882a3f5...
# 7   [26, Pepsi Center, sg:e7385ac76b2546c9b905be12...
# 8   [26, Nationwide Arena, sg:496bf83aad094f17b605...
# 9   [26, American Airlines Center, sg:f79998a4f42d...
# 10  [26, Joe Louis Arena, sg:bc9119e31f654fbebc5f5...
# 11                                               None
# 12  [26, Bb&t Center, sg:21817b805e2440458fe155b60...
# 13  [26, Staples Center, sg:c4899bdca8564210a4cbc6...
# 14  [26, Xcel Energy Center, sg:08fa621a2cb740d8a3...
# 15                                               None
# 16  [26, Bridgestone Arena, sg:58eb00db004c4967abd...
# 17  [26, Prudential Center, sg:357526853991422fb9d...
# 18  [26, Barclays Center, sg:a4375f84884541bca5628...
# 19  [26, Madison Square Garden, sg:1cc8dbe5600542c...
# 20                                               None
# 21  [26, Wells Fargo Center, sg:781e08237713408aa4...
# 22  [25, PPG Paints Arena, sg:1b1e67f2b8224e9ba261...
# 23  [26, Sap Center At San Jose, sg:e93a3b16182849...
# 24  [26, Scottrade Center, sg:f4fcc878943045c2b6a9...
# 25  [26, Amalie Arena, sg:ae234e2aadac4cfe817252fb...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  [26, Verizon Center, sg:008eedc461cd430f8be8e2...
# 30                                               None
#
#                                       good_match_2018  \
# 0   [2, Honda Center, sg:1a660f827ee040e5bbb6da664...
# 1                                                None
# 2   [26, Td Garden, sg:2a96716e3b8a4f0e9dfc249ac7c...
# 3   [26, First Niagara Center, sg:74d5a8291f1345b4...
# 4                                                None
# 5   [26, Pnc Arena, sg:ac283081b6e44c1cb19feb1a5ce...
# 6   [26, United Center, sg:ae4d4adf1c4a4ace882a3f5...
# 7   [26, Pepsi Center, sg:e7385ac76b2546c9b905be12...
# 8   [26, Nationwide Arena, sg:496bf83aad094f17b605...
# 9   [26, American Airlines Center, sg:f79998a4f42d...
# 10  [26, Little Caesars Arena, sg:461065e801484d2e...
# 11                                               None
# 12  [26, Bb&t Center, sg:21817b805e2440458fe155b60...
# 13  [26, Staples Center, sg:c4899bdca8564210a4cbc6...
# 14  [26, Xcel Energy Center, sg:08fa621a2cb740d8a3...
# 15                                               None
# 16  [26, Bridgestone Arena, sg:58eb00db004c4967abd...
# 17  [26, Prudential Center, sg:357526853991422fb9d...
# 18  [26, Barclays Center, sg:a4375f84884541bca5628...
# 19  [26, Madison Square Garden, sg:1cc8dbe5600542c...
# 20                                               None
# 21  [26, Wells Fargo Center, sg:781e08237713408aa4...
# 22  [25, PPG Paints Arena, sg:1b1e67f2b8224e9ba261...
# 23  [26, Sap Center At San Jose, sg:e93a3b16182849...
# 24  [26, Scottrade Center, sg:f4fcc878943045c2b6a9...
# 25  [26, Amalie Arena, sg:ae234e2aadac4cfe817252fb...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  [26, Verizon Center, sg:008eedc461cd430f8be8e2...
# 30                                               None
#
#                                       good_match_2019
# 0   [2, Honda Center, sg:1a660f827ee040e5bbb6da664...
# 1                                                None
# 2   [26, Td Garden, sg:2a96716e3b8a4f0e9dfc249ac7c...
# 3   [26, First Niagara Center, sg:74d5a8291f1345b4...
# 4                                                None
# 5   [26, Pnc Arena, sg:ac283081b6e44c1cb19feb1a5ce...
# 6   [26, United Center, sg:ae4d4adf1c4a4ace882a3f5...
# 7   [26, Pepsi Center, sg:e7385ac76b2546c9b905be12...
# 8   [26, Nationwide Arena, sg:496bf83aad094f17b605...
# 9   [26, American Airlines Center, sg:f79998a4f42d...
# 10  [26, Little Caesars Arena, sg:461065e801484d2e...
# 11                                               None
# 12  [26, Bb&t Center, sg:21817b805e2440458fe155b60...
# 13  [26, Staples Center, sg:c4899bdca8564210a4cbc6...
# 14  [26, Xcel Energy Center, sg:08fa621a2cb740d8a3...
# 15                                               None
# 16  [26, Bridgestone Arena, sg:58eb00db004c4967abd...
# 17  [26, Prudential Center, sg:357526853991422fb9d...
# 18  [26, Barclays Center, sg:a4375f84884541bca5628...
# 19  [26, Madison Square Garden, sg:1cc8dbe5600542c...
# 20                                               None
# 21  [26, Wells Fargo Center, sg:781e08237713408aa4...
# 22  [25, PPG Paints Arena, sg:1b1e67f2b8224e9ba261...
# 23  [26, Sap Center At San Jose, sg:e93a3b16182849...
# 24  [26, Enterprise Center, sg:e130db7760b14d55846...
# 25  [26, Amalie Arena, sg:ae234e2aadac4cfe817252fb...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  [26, Verizon Center, sg:008eedc461cd430f8be8e2...
# 30                                               None

# %%
towns
# Out:
#                      Team                         City
# 0           Anaheim Ducks          Anaheim, California
# 1         Arizona Coyotes            Glendale, Arizona
# 2           Boston Bruins        Boston, Massachusetts
# 3          Buffalo Sabres            Buffalo, New York
# 4          Calgary Flames             Calgary, Alberta
# 5     Carolina Hurricanes      Raleigh, North Carolina
# 6      Chicago Blackhawks            Chicago, Illinois
# 7      Colorado Avalanche             Denver, Colorado
# 8   Columbus Blue Jackets               Columbus, Ohio
# 9            Dallas Stars                Dallas, Texas
# 10      Detroit Red Wings            Detroit, Michigan
# 11        Edmonton Oilers            Edmonton, Alberta
# 12       Florida Panthers             Sunrise, Florida
# 13      Los Angeles Kings      Los Angeles, California
# 14         Minnesota Wild        Saint Paul, Minnesota
# 15     Montreal Canadiens             Montreal, Quebec
# 16    Nashville Predators         Nashville, Tennessee
# 17      New Jersey Devils           Newark, New Jersey
# 18     New York Islanders      New York City, New York
# 19       New York Rangers      New York City, New York
# 20        Ottawa Senators              Ottawa, Ontario
# 21    Philadelphia Flyers   Philadelphia, Pennsylvania
# 22    Pittsburgh Penguins     Pittsburgh, Pennsylvania
# 23        San Jose Sharks         San Jose, California
# 24        St. Louis Blues          St. Louis, Missouri
# 25    Tampa Bay Lightning               Tampa, Florida
# 26    Toronto Maple Leafs             Toronto, Ontario
# 27      Vancouver Canucks  Vancouver, British Columbia
# 28   Vegas Golden Knights             Paradise, Nevada
# 29    Washington Capitals             Washington, D.C.
# 30          Winnipeg Jets           Winnipeg, Manitoba

# %%
stadiums['sg_id_2017'] = stadiums['good_match_2017'].apply(lambda x: x[2] if x else None)
stadiums['sg_id_2018'] = stadiums['good_match_2018'].apply(lambda x: x[2] if x else None)
stadiums['sg_id_2019'] = stadiums['good_match_2019'].apply(lambda x: x[2] if x else None)

# %%
# Export the matching
output_file_path = os.path.join(teams_output_folder, 'hockey_matching.csv')
stadiums[['name', 'sg_id_2017', 'sg_id_2018', 'sg_id_2019']].to_csv(output_file_path, 
                                                                    index = False)
